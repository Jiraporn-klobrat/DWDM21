# %% [markdown]
# <a href="https://colab.research.google.com/github/Jiraporn-klobrat/DWDM21/blob/main/Project_DWDM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project กลุ่ม**
# *   ข้อมูลที่ไปดึงมาจาก 3 แหล่ง
# *   แสดงวิธีการโหลด
# *   ความเชื่อมโยงของ 3 ตาราง (index)

# %% [markdown]
# # **รายชื่อสมาชิกในกลุ่ม**
# **ชื่อกลุ่ม** : เอกาไร้สติ
# 1. นางสาวกัญญาวีร์ ศรีเทียมเงิน 623020511-1
#
# 2. นางสาวชลธิชา ศาลางาม 623020518-7
#
# 3. นางสาวสุภาภรณ์ บุตุธรรม 623020543-8
#
# 4. นางสาวจิราพร กลบรัตน์ 623020762-6
#
# 5. นางสาววิกานดา หงษ์บุญมี 623020764-2
#
#     ***Data Warehouse & Data Mining 2021***

# %% [markdown]
# # **แหล่งที่มาของข้อมูล**
# 1. รับเรื่องร้องเรียน/แจ้งเบาะแสยาเสพติด องค์กร : สำนักงานคณะกรรมการป้องกันและปราบปรามยาเสพติด
#
# 2. ปริมาณของกลางยาเสพติด องค์กร : สำนักงานคณะกรรมการป้องกันและปราบปรามยาเสพติด
#
# 3. จำนวนคดี ผู้ต้องหาคดียาเสพติด  องค์กร : สำนักงานคณะกรรมการป้องกันและปราบปรามยาเสพติด
#
# 4. ข้อมูลทั่วไปของจังหวัด

# %% [markdown]
# Link Drive ที่รวมข้อมูล : https://drive.google.com/drive/folders/1lT7yOhBQxr-_vbsrogIDKaD6ISxta9qK?usp=sharing

# %% [markdown]
# # **ปัญหา**
# คือ เพื่อทำนายชนิดของยาเสพติด โดยใช้จำนวนประชากร, พื้นที่, รายได้เฉลี่ยต่อเดือนของครัวเรือน,จำนวนเรื่องร้องเรียน/แจ้งเบาะแสยาเสพติด,ปริมาณของกลางยาเสพติดและจำนวนคดีผู้ต้องหาคดียาเสพติด

# %%
import pandas as pd  # pandas เป็น Package ที่ใช้เกี่ยวกับการจัดการข้อมูลที่เป็นตาราง , เรียกใช้โดยการ import แล้วตามด้วยชื่อ Package

# %%
from google.colab import drive  # เชื่อมต่อกับ google drive ที่เราเก็บข้อมูลไว้
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os # เป็น package ที่เอาไว้จัดการไฟล์และเอาไว้ดูที่มาของไฟล์หรือ path

# %%
path = '/content/drive/My Drive/DWDM2021_DATAPROJECT' #ระบุให้ชี้ไปที่โฟลเดอร์ใน google drive ที่เราเซฟไฟล์ไว้ คือ โฟลเดอร์ DWDM2021_DATAPROJECT

# %% [markdown]
# # **ชุดข้อมูลที่ 1 รับเรื่องร้องเรียน/แจ้งเบาะแสยาเสพติด**

# %%
data_01 = pd.read_csv(os.path.join(path,'รับเรื่องร้องเรียนยาเสพติด.csv')) # ไฟล์ที่เราต้องการ
data_01 # print data ดูว่ามันหน้าตาเป็นยังไง
# Out:
#     รหัสจังหวัด  ... เปอร์เซ็นต์การดำเนินการต่อเรื่องร้องเรียนและแจ้งเบาะแสยาเสพติด บุคคล (%)
# 0            11  ...                                              97.81
# 1            12  ...                                             100.00
# 2            13  ...                                              97.26
# 3            14  ...                                              99.13
# 4            15  ...                                             100.00
# ..          ...  ...                                                ...
# 72           93  ...                                             100.00
# 73           94  ...                                             100.00
# 74           95  ...                                             100.00
# 75           96  ...                                             100.00
# 76           10  ...                                              93.52
#
# [77 rows x 11 columns]

# %% [markdown]
# ### **คำอธิบายตาราง**
#
# *   **รหัสจังหวัด**	คือ รหัสจังหวัดที่รับเรื่องร้องเรียน/แจ้งเบาะแสยาเสพติด
# *   **ชื่อจังหวัด** คือ ชื่อจังหวัดที่รับเรื่องร้องเรียน/แจ้งเบาะแสยาเสพติด
# *   **เรื่องร้องเรียนและแจ้งเบาะแสยาเสพติดทั้งหมด (เรื่อง)** คือ จำนวนของเรื่องร้องเรียนและแจ้งเบาะแสยาเสพติดทั้งหมด (เรื่อง)
# *   **การดำเนินการต่อเรื่องร้องเรียนและแจ้งเบาะแสยาเสพติดทั้งหมด (เรื่อง)** คือ จำนวนของการดำเนินการต่อเรื่องร้องเรียนและแจ้งเบาะแสยาเสพติดทั้งหมด (เรื่อง)
# *   **เปอร์เซ็นต์การดำเนินการต่อเรื่องร้องเรียนและแจ้งเบาะแสยาเสพติดทั้งหมด (%)** คือ เปอร์เซ็นต์ของการดำเนินการต่อเรื่องร้องเรียนและแจ้งเบาะแสยาเสพติดทั้งหมด (%)
# *   **เรื่องร้องเรียนและแจ้งเบาะแสยาเสพติด พื้นที่ (เรื่อง)** คือ จำนวนของเรื่องร้องเรียนและแจ้งเบาะแสยาเสพติด แยกตามพื้นที่ที่รับเรื่องร้องเรียน/แจ้งเบาะแสยาเสพติด (เรื่อง)
# *   **การดำเนินการต่อเรื่องร้องเรียนและแจ้งเบาะแสยาเสพติด พื้นที่ (เรื่อง)** คือ จำนวนของการดำเนินการต่อเรื่องร้องเรียนและแจ้งเบาะแสยาเสพติด แยกตามพื้นที่ที่รับเรื่องร้องเรียน/แจ้งเบาะแสยาเสพติด(เรื่อง)
# *   **เปอร์เซ็นต์การดำเนินการต่อเรื่องร้องเรียนและแจ้งเบาะแสยาเสพติด พื้นที่ (%)**คือ เปอร์เซ็นต์ของการดำเนินการต่อเรื่องร้องเรียนและแจ้งเบาะแสยาเสพติด แยกตามพื้นที่ที่รับเรื่องร้องเรียน/แจ้งเบาะแสยาเสพติด (%)
# *   **เรื่องร้องเรียนและแจ้งเบาะแสยาเสพติด บุคคล (เรื่อง)** คือ จำนวนเรื่องร้องเรียนและแจ้งเบาะแสยาเสพติด แยกตามบุคคลที่รับเรื่องร้องเรียน/แจ้งเบาะแสยาเสพติด (เรื่อง)
# *   **การดำเนินการต่อเรื่องร้องเรียนและแจ้งเบาะแสยาเสพติด บุคคล (เรื่อง)** คือ จำนวนการดำเนินการต่อเรื่องร้องเรียนและแจ้งเบาะแสยาเสพติด แยกตามบุคคลที่รับเรื่องร้องเรียน/แจ้งเบาะแสยาเสพติด (เรื่อง)
# *   **เปอร์เซ็นต์การดำเนินการต่อเรื่องร้องเรียนและแจ้งเบาะแสยาเสพติด บุคคล (%)** คือ เปอร์เซ็นต์ของการดำเนินการต่อเรื่องร้องเรียนและแจ้งเบาะแสยาเสพติด แยกตามบุคคลที่รับเรื่องร้องเรียน/แจ้งเบาะแสยาเสพติด (%)

# %%
data_01 = data_01.sort_values(by=['รหัสจังหวัด']) # เรียงข้อมูลตามรหัสจังหวัด 
data_01
# Out:
#     รหัสจังหวัด  ... เปอร์เซ็นต์การดำเนินการต่อเรื่องร้องเรียนและแจ้งเบาะแสยาเสพติด บุคคล (%)
# 76           10  ...                                              93.52
# 0            11  ...                                              97.81
# 1            12  ...                                             100.00
# 2            13  ...                                              97.26
# 3            14  ...                                              99.13
# ..          ...  ...                                                ...
# 71           92  ...                                             100.00
# 72           93  ...                                             100.00
# 73           94  ...                                             100.00
# 74           95  ...                                             100.00
# 75           96  ...                                             100.00
#
# [77 rows x 11 columns]

# %% [markdown]
# ### **ตรวจสอบค่า Missing ของตาราง data_01**

# %%
data_01.isnull() # ตรงไหนเป็นช่องว่างจะขึ้นว่า True ตรงไหนไม่เป็นช่องว่างจะขึ้นว่า False
# Out:
#     รหัสจังหวัด  ...  เปอร์เซ็นต์การดำเนินการต่อเรื่องร้องเรียนและแจ้งเบาะแสยาเสพติด บุคคล (%)
# 76        False  ...                                              False
# 0         False  ...                                              False
# 1         False  ...                                              False
# 2         False  ...                                              False
# 3         False  ...                                              False
# ..          ...  ...                                                ...
# 71        False  ...                                              False
# 72        False  ...                                              False
# 73        False  ...                                              False
# 74        False  ...                                              False
# 75        False  ...                                              False
#
# [77 rows x 11 columns]

# %%
data_01.isnull().any() # ดูว่าคอลัมน์ไหนมีค่า missing บ้าง สรุปคือทุกคอลัมน์ไม่มีค่า  missing
# Out:
# รหัสจังหวัด                                                                   False
# ชื่อจังหวัด                                                                   False
# เรื่องร้องเรียนและแจ้งเบาะแสยาเสพติดทั้งหมด (เรื่อง)                          False
# การดำเนินการต่อเรื่องร้องเรียนและแจ้งเบาะแสยาเสพติดทั้งหมด (เรื่อง)           False
# เปอร์เซ็นต์การดำเนินการต่อเรื่องร้องเรียนและแจ้งเบาะแสยาเสพติดทั้งหมด (%)     False
# เรื่องร้องเรียนและแจ้งเบาะแสยาเสพติด พื้นที่ (เรื่อง)                         False
# การดำเนินการต่อเรื่องร้องเรียนและแจ้งเบาะแสยาเสพติด พื้นที่ (เรื่อง)          False
# เปอร์เซ็นต์การดำเนินการต่อเรื่องร้องเรียนและแจ้งเบาะแสยาเสพติด พื้นที่ (%)    False
# เรื่องร้องเรียนและแจ้งเบาะแสยาเสพติด บุคคล (เรื่อง)                           False
# การดำเนินการต่อเรื่องร้องเรียนและแจ้งเบาะแสยาเสพติด บุคคล (เรื่อง)            False
# เปอร์เซ็นต์การดำเนินการต่อเรื่องร้องเรียนและแจ้งเบาะแสยาเสพติด บุคคล (%)      False
# dtype: bool

# %% [markdown]
# # **ชุดข้อมูลที่ 2 ปริมาณของกลางยาเสพติด**

# %%
data_02 = pd.read_csv(os.path.join(path,'ปริมาณของกลางยาเสพติด.csv')) # ไฟล์ที่เราต้องการ
data_02 # print data ดูว่ามันหน้าตาเป็นยังไง
# Out:
#     รหัสจังหวัด        จังหวัด  ...  โคเคน (กิโลกรัม) กระท่อม (กิโลกรัม)
# 0            32       สุรินทร์  ...             0.000           35.07000
# 1            41       อุดรธานี  ...             0.000            0.26000
# 2            49       มุกดาหาร  ...             0.000            0.58500
# 3            47         สกลนคร  ...             0.000           24.53000
# 4            46      กาฬสินธุ์  ...             0.000            0.00000
# ..          ...            ...  ...               ...                ...
# 72           92           ตรัง  ...             0.000         1772.45500
# 73           93         พัทลุง  ...             0.000         1242.31250
# 74           94        ปัตตานี  ...             0.000         5950.30800
# 75           95           ยะลา  ...             0.000         4043.89700
# 76           10  กรุงเทพมหานคร  ...             0.049         2755.81611
#
# [77 rows x 11 columns]

# %% [markdown]
# ### **คำอธิบายตาราง**
#
# *   **รหัสจังหวัด** คือ รหัสของจังหวัดที่พบของกลางยาเสพติด
# *   **จังหวัด** คือ ชื่อของจังหวัดที่พบของกลางยาเสพติด
# *   **ปริมาณของกลางยาเสพติดทั้งหมด (กิโลกรัม)** คือ ปริมาณของกลางยาเสพติดที่พบในแต่ละจังหวัดทั้งหมด (กิโลกรัม)
# *   **ชนิดของกลางยาเสพติด** คือ ชนิดของยาเสพติดที่พบในแต่ละจังหวัด
# *   **ยาบ้า (กิโลกรัม)** คือ ปริมาณของยาบ้าที่พบในแต่ละจังหวัด (กิโลกรัม)
# *   **ไอซ์ (กิโลกรัม)** คือ ปริมาณของยาไอซ์ที่พบในแต่ละจังหวัด (กิโลกรัม)
# *   **กัญชาแห้ง (กิโลกรัม)** คือ ปริมาณของกัญชาแห้งที่พบในแต่ละจังหวัด (กิโลกรัม)
# *   **เฮโรอีน (กิโลกรัม)** คือ ปริมาณของเฮโรอีนที่พบในแต่ละจังหวัด (กิโลกรัม)
# *   **คีตามีน (กิโลกรัม)** คือ ปริมาณของคีตามีนที่พบในแต่ละจังหวัด (กิโลกรัม)
# *   **โคเคน (กิโลกรัม)** คือ ปริมาณของโคเคนที่พบในแต่ละจังหวัด (กิโลกรัม)
# *   **กระท่อม (กิโลกรัม)** คือ ปริมาณของกระท่อมที่พบในแต่ละจังหวัด (กิโลกรัม)

# %%
data_02 = data_02.sort_values(by=['รหัสจังหวัด']) # เรียงข้อมูลตามรหัสจังหวัด 
data_02
# Out:
#     รหัสจังหวัด          จังหวัด  ...  โคเคน (กิโลกรัม) กระท่อม (กิโลกรัม)
# 76           10    กรุงเทพมหานคร  ...             0.049         2755.81611
# 24           11      สมุทรปราการ  ...             0.000          332.85821
# 25           12          นนทบุรี  ...             0.030          626.33734
# 26           13         ปทุมธานี  ...             0.000          981.02860
# 27           14  พระนครศรีอยุธยา  ...             0.000          932.65946
# ..          ...              ...  ...               ...                ...
# 72           92             ตรัง  ...             0.000         1772.45500
# 73           93           พัทลุง  ...             0.000         1242.31250
# 74           94          ปัตตานี  ...             0.000         5950.30800
# 75           95             ยะลา  ...             0.000         4043.89700
# 69           96         นราธิวาส  ...             0.000         5569.70900
#
# [77 rows x 11 columns]

# %% [markdown]
# ### **ตรวจสอบค่า Missing ของตาราง data_02**

# %%
data_02.isnull() # ตรงไหนเป็นช่องว่างจะขึ้นว่า True ตรงไหนไม่เป็นช่องว่างจะขึ้นว่า False
# Out:
#     รหัสจังหวัด  จังหวัด  ...  โคเคน (กิโลกรัม)  กระท่อม (กิโลกรัม)
# 76        False    False  ...             False               False
# 24        False    False  ...             False               False
# 25        False    False  ...             False               False
# 26        False    False  ...             False               False
# 27        False    False  ...             False               False
# ..          ...      ...  ...               ...                 ...
# 72        False    False  ...             False               False
# 73        False    False  ...             False               False
# 74        False    False  ...             False               False
# 75        False    False  ...             False               False
# 69        False    False  ...             False               False
#
# [77 rows x 11 columns]

# %%
data_02.isnull().any() # ดูว่าคอลัมน์ไหนมีค่า missing บ้าง สรุปคือทุกคอลัมน์ไม่มีค่า  missing
# Out:
# รหัสจังหวัด                                False
# จังหวัด                                    False
# ปริมาณของกลางยาเสพติดทั้งหมด (กิโลกรัม)    False
# ชนิดของกลางยาเสพติด                        False
# ยาบ้า (กิโลกรัม)                           False
# ไอซ์ (กิโลกรัม)                            False
# กัญชาแห้ง (กิโลกรัม)                       False
# เฮโรอีน (กิโลกรัม)                         False
# คีตามีน (กิโลกรัม)                         False
# โคเคน (กิโลกรัม)                           False
# กระท่อม (กิโลกรัม)                         False
# dtype: bool

# %%
data_02_cut = data_02.iloc[:,4:] # เลือกเฉพาะคอลัมน์ที่เป็นจำนวนของปริมาณยาเสพติด (กิโลกรัม)
data_02_cut
# Out:
#     ยาบ้า (กิโลกรัม)  ไอซ์ (กิโลกรัม)  ...  โคเคน (กิโลกรัม)  กระท่อม (กิโลกรัม)
# 76          182.0511        336.05174  ...             0.049          2755.81611
# 24           16.8905         35.66841  ...             0.000           332.85821
# 25           87.8015         13.21964  ...             0.030           626.33734
# 26          121.0734         40.26200  ...             0.000           981.02860
# 27          636.6864         26.73300  ...             0.000           932.65946
# ..               ...              ...  ...               ...                 ...
# 72          248.9255         10.50600  ...             0.000          1772.45500
# 73           63.0449          4.14783  ...             0.000          1242.31250
# 74          352.6543        378.82900  ...             0.000          5950.30800
# 75          176.9054         21.12000  ...             0.000          4043.89700
# 69          342.2397       2177.68196  ...             0.000          5569.70900
#
# ...

# %%
data_02_value = data_02_cut.values # แปลงจากตารางให้กลายเป็นค่าของข้อมูล
data_02_value
# Out:
# array([[1.82051100e+02, 3.36051740e+02, 4.33377000e+02, 9.38900000e+00,
#         5.33120000e+00, 4.90000000e-02, 2.75581611e+03],
#        [1.68905000e+01, 3.56684100e+01, 1.70812000e+01, 1.00000000e-03,
#         9.55000000e-01, 0.00000000e+00, 3.32858210e+02],
#        [8.78015000e+01, 1.32196400e+01, 1.31890000e+01, 5.13000000e-01,
#         7.89000000e-01, 3.00000000e-02, 6.26337340e+02],
#        [1.21073400e+02, 4.02620000e+01, 7.21630000e+01, 1.71000000e-01,
#         7.31000000e-01, 0.00000000e+00, 9.81028600e+02],
#        [6.36686400e+02, 2.67330000e+01, 2.80200000e+00, 0.00000000e+00,
#         1.00000000e-02, 0.00000000e+00, 9.32659460e+02],
#        [2.19895400e+02, 6.23914000e+00, 2.78400000e+00, 7.20000000e-02,
#         3.40000000e-02, 0.00000000e+00, 3.85900000e+02],
#        [1.54666800e+02, 3.46300000e+00, 2.16700000e+00, 0.00000000e+00,
#         6.70000000e-02, 0.00000000e+00, 1.07000000e+01],
# ...

# %%
import numpy as np
max_all = np.zeros(data_02_value.shape[0]) # หาค่าที่มากที่สุดของแต่ละแถวเพื่อดูว่ายาเสพติดชนิดที่พบมากที่สุดมีปริมาณเท่าไหร่
for row in range(data_02_value.shape[0]):
    max_all[row] = max(data_02_value[row,:])
print(max_all)
# Out:
# [2.75581611e+03 3.32858210e+02 6.26337340e+02 9.81028600e+02
#  9.32659460e+02 3.85900000e+02 1.54666800e+02 5.14725000e+01
#  1.08513000e+02 5.91140000e+02 5.21596000e+02 5.69710000e+01
#  6.04940000e+01 4.16274000e+02 5.78895000e+01 2.89320000e+01
#  5.42737000e+02 4.91995600e+01 3.01773000e+02 7.79296000e+01
#  5.02577000e+01 1.30678400e+02 5.03481000e+02 4.23811000e+01
#  5.87532000e+01 7.53441000e+01 1.30539320e+03 2.90345000e+01
#  4.59846000e+02 1.41344300e+02 6.36172000e+01 1.21472780e+03
#  6.91882000e+01 9.00012000e+01 2.53982600e+02 6.70285000e+02
#  9.69362800e+02 6.79700000e+02 3.88423520e+03 1.77913600e+02
#  1.24196880e+03 5.11268000e+01 6.60400500e+02 1.21619000e+01
#  3.16730000e+01 3.54830150e+03 4.60160000e+00 3.79929000e+01
#  3.22070000e+00 5.61840000e+01 1.50032800e+03 3.01403000e+01
#  2.78173000e+01 1.40540000e+01 1.32001000e+02 4.85322590e+02
#  1.39515700e+03 4.17618000e+01 4.62830000e+01 1.14475550e+02
# ...

# %%
max_all = pd.DataFrame(max_all) # ดูว่าปริมาณของยาเสพติดที่พบมากที่สุดของแต่ละแถวหรือแต่ละจังหวัดเป็นเท่าไหร่
print(max_all)
# Out:
#              0
# 0   2755.81611
# 1    332.85821
# 2    626.33734
# 3    981.02860
# 4    932.65946
# ..         ...
# 72  1772.45500
# 73  1242.31250
# 74  5950.30800
# 75  4043.89700
# 76  5569.70900
#
# [77 rows x 1 columns]

# %%
data_02 = data_02.assign(max_all = max_all.values) # เพิ่มคอลัมน์ของ max_all เข้าไปยังตารางข้อมูล
data_02
# Out:
#     รหัสจังหวัด          จังหวัด  ...  กระท่อม (กิโลกรัม)     max_all
# 76           10    กรุงเทพมหานคร  ...          2755.81611  2755.81611
# 24           11      สมุทรปราการ  ...           332.85821   332.85821
# 25           12          นนทบุรี  ...           626.33734   626.33734
# 26           13         ปทุมธานี  ...           981.02860   981.02860
# 27           14  พระนครศรีอยุธยา  ...           932.65946   932.65946
# ..          ...              ...  ...                 ...         ...
# 72           92             ตรัง  ...          1772.45500  1772.45500
# 73           93           พัทลุง  ...          1242.31250  1242.31250
# 74           94          ปัตตานี  ...          5950.30800  5950.30800
# 75           95             ยะลา  ...          4043.89700  4043.89700
# 69           96         นราธิวาส  ...          5569.70900  5569.70900
#
# [77 rows x 12 columns]

# %%
data_02.rename(columns={'max_all':'ปริมาณของกลางยาเสพติดที่พบมากที่สุด (กิโลกรัม)'}, inplace=True) # เปลี่ยนชื่อคอลัมน์
data_02
# Out:
#     รหัสจังหวัด  ... ปริมาณของกลางยาเสพติดที่พบมากที่สุด (กิโลกรัม)
# 76           10  ...                                     2755.81611
# 24           11  ...                                      332.85821
# 25           12  ...                                      626.33734
# 26           13  ...                                      981.02860
# 27           14  ...                                      932.65946
# ..          ...  ...                                            ...
# 72           92  ...                                     1772.45500
# 73           93  ...                                     1242.31250
# 74           94  ...                                     5950.30800
# 75           95  ...                                     4043.89700
# 69           96  ...                                     5569.70900
#
# [77 rows x 12 columns]

# %%
data_02.sort_values(by='ปริมาณของกลางยาเสพติดที่พบมากที่สุด (กิโลกรัม)') # เรียงข้อมูลตามปริมาณของกลางยาเสพติดที่พบมากที่สุด (กิโลกรัม)
# Out:
#     รหัสจังหวัด  ... ปริมาณของกลางยาเสพติดที่พบมากที่สุด (กิโลกรัม)
# 51           61  ...                                         3.2207
# 19           58  ...                                         4.6016
# 16           55  ...                                        12.1619
# 23           66  ...                                        14.0540
# 48           65  ...                                        27.8173
# ..          ...  ...                                            ...
# 75           95  ...                                      4043.8970
# 69           96  ...                                      5569.7090
# 74           94  ...                                      5950.3080
# 62           84  ...                                      7767.3641
# 70           90  ...                                     26727.6536
#
# [77 rows x 12 columns]

# %%
# ดูว่ามียาเสพติดชนิดใดบ้างที่พบปริมาณมากที่สุด เมื่อพิจารณาจากปริมาณของกลางยาเสพติดที่พบมากที่สุด (กิโลกรัม)
data_02.groupby(['ชนิดของกลางยาเสพติด']).sum().sort_values(by='ปริมาณของกลางยาเสพติดที่พบมากที่สุด (กิโลกรัม)')
# Out:
#                       รหัสจังหวัด  ...  ปริมาณของกลางยาเสพติดที่พบมากที่สุด (กิโลกรัม)
# ชนิดของกลางยาเสพติด                ...
# กัญชาแห้ง (กิโลกรัม)          203  ...                                      1941.83200
# ไอซ์ (กิโลกรัม)               238  ...                                      4386.03556
# ยาบ้า (กิโลกรัม)             1546  ...                                     15438.41810
# กระท่อม (กิโลกรัม)           1950  ...                                     78567.68158
#
# [4 rows x 10 columns]

# %%
data_02['ชนิดของกลางยาเสพติด'].replace({  # ตรงคอลัมน์ ชนิดของกลางยาเสพติด ลบหน่วยคำว่า (กิโลกรัม) ออกไปให้เหลือแค่ชื่อของชนิดยาเสพติดเพียงอย่างเดียว
        'กัญชาแห้ง (กิโลกรัม)':'กัญชาแห้ง',
        'ไอซ์ (กิโลกรัม)':'ไอซ์',
        'ยาบ้า (กิโลกรัม)':'ยาบ้า',
        'กระท่อม (กิโลกรัม)':'กระท่อม'
    }, inplace=True)
data_02
# Out:
#     รหัสจังหวัด  ... ปริมาณของกลางยาเสพติดที่พบมากที่สุด (กิโลกรัม)
# 76           10  ...                                     2755.81611
# 24           11  ...                                      332.85821
# 25           12  ...                                      626.33734
# 26           13  ...                                      981.02860
# 27           14  ...                                      932.65946
# ..          ...  ...                                            ...
# 72           92  ...                                     1772.45500
# 73           93  ...                                     1242.31250
# 74           94  ...                                     5950.30800
# 75           95  ...                                     4043.89700
# 69           96  ...                                     5569.70900
#
# [77 rows x 12 columns]

# %%
# ดูว่ามียาเสพติดชนิดใดบ้างที่พบปริมาณมากที่สุด เมื่อพิจารณาจากปริมาณของกลางยาเสพติดที่พบมากที่สุด (กิโลกรัม)
data_02.groupby(['ชนิดของกลางยาเสพติด']).sum().sort_values(by='ปริมาณของกลางยาเสพติดที่พบมากที่สุด (กิโลกรัม)')
# Out:
#                      รหัสจังหวัด  ...  ปริมาณของกลางยาเสพติดที่พบมากที่สุด (กิโลกรัม)
# ชนิดของกลางยาเสพติด               ...
# กัญชาแห้ง                    203  ...                                      1941.83200
# ไอซ์                         238  ...                                      4386.03556
# ยาบ้า                       1546  ...                                     15438.41810
# กระท่อม                     1950  ...                                     78567.68158
#
# [4 rows x 10 columns]

# %% [markdown]
# จากตารางข้างต้นพบว่า ชนิดของกลางยาเสพติดที่พบมากที่สุด คือ กัญชาแห้ง, ไอซ์, ยาบ้า และกระท่อม เมื่อพิจารณาจากปริมาณของกลางยาเสพติดที่พบมากที่สุด (กิโลกรัม)

# %% [markdown]
# # **ชุดข้อมูลที่ 3 จำนวนคดี ผู้ต้องหาคดียาเสพติด**

# %%
data_03 = pd.read_csv(os.path.join(path,'คดีผู้องหาคดียาเสพติด.csv')) # ไฟล์ที่เราต้องการ
data_03 # print data ดูว่ามันหน้าตาเป็นยังไง
# Out:
#     ปีงบประมาณ  ...  จำนวนผู้ต้องหาคดี 5 ข้อหาหลัก (คน)
# 0         2563  ...                                1198
# 1         2563  ...                                 596
# 2         2563  ...                                1433
# 3         2563  ...                                 913
# 4         2563  ...                                1857
# ..         ...  ...                                 ...
# 72        2563  ...                                3043
# 73        2563  ...                                1619
# 74        2563  ...                                2164
# 75        2563  ...                                 834
# 76        2563  ...                                 881
#
# [77 rows x 22 columns]

# %% [markdown]
# ### **คำอธิบายตาราง**
#
# *   **ปีงบประมาณ** คือ ปีงบประมาณของจำนวนคดีและจำนวนผู้ต้องหาคดียาเสพติด
# *   **รหัสจังหวัด** คือ รหัสของจังหวัดที่มีคดียาเสพติดและผู้ต้องหาคดียาเสพติด
# *   **จำนวนคดีทั้งหมด (คดี)** คือ จำนวนของคดียาเสพติดทั้งหมด (คดี)
# *   **จำนวนผู้ต้องหาทั้งหมด (คน)** คือ จำนวนของผู้ต้องหาคดียาเสพติดทั้งหมด (คน)
# *   **จำนวนคดีเสพ (คดี)** คือ จำนวนคดียาเสพติดข้อหาเสพยาเสพติดทั้งหมด (คดี)
# *  **จำนวนผู้ต้องหาคดีเสพ (คน)** คือ จำนวนผู้ต้องหาคดียาเสพติดข้อหาเสพยาเสพติดทั้งหมด (คน)
# *   **จำนวนคดีครอบครอง (คดี)** คือ จำนวนคดียาเสพติดข้อหาครอบครองยาเสพติดทั้งหมด (คดี)
# *   **จำนวนผู้ต้องหาคดีครอบครอง (คน)** คือ จำนวนของผู้ต้องหาคดียาเสพติดข้อหาครอบครองยาเสพติดทั้งหมด (คน)
# *   **จำนวนคดีครอบครองเพื่อจำหน่าย (คดี)** คือ จำนวนคดียาเสพติดข้อหาครอบครองเพื่อจำหน่ายยาเสพติดทั้งหมด (คดี)
# *   **จำนวนผู้ต้องหาคดีครอบครองเพื่อจำหน่าย (คน)** คือ จำนวนผู้ต้องหาคดียาเสพติดข้อหาครอบครองเพื่อจำหน่ายยาเสพติดทั้งหมด (คน)
# *   **จำนวนคดีจำหน่าย (คดี)** คือ จำนวนคดียาเสพติดข้อหาจำหน่ายยาเสพติดทั้งหมด (คดี)
# *   **จำนวนผู้ต้องหาคดีจำหน่าย (คน)** คือ จำนวนผู้ต้องหาคดียาเสพติดข้อหาจำหน่ายยาเสพติดทั้งหมด (คน)
# *   **จำนวนคดีผลิต (คดี)** คือ จำนวนคดียาเสพติดข้อหาผลิตยาเสพติดทั้งหมด (คดี)
# *   **จำนวนผู้ต้องหาคดีผลิต (คน)** คือ จำนวนผู้ต้องหาคดียาเสพติดข้อหาผลิตยาเสพติดทั้งหมด (คน)
# *   **จำนวนคดีนำเข้า (คดี)** คือ จำนวนคดียาเสพติดข้อหานำเข้ายาเสพติดทั้งหมด (คดี)
# *   **จำนวนผู้ต้องหาคดีนำเข้า (คน)** คือ จำนวนผู้ต้องหาคดียาเสพติดข้อหานำเข้ายาเสพติดทั้งหมด (คน)
# *   **จำนวนคดีส่งออก (คดี)** คือ จำนวนคดียาเสพติดข้อหาส่งออกยาเสพติดทั้งหมด (คดี)
# *   **จำนวนผู้ต้องหาคดีส่งออก (คน)** คือ จำนวนผู้ต้องหาคดียาเสพติดข้อหาส่งออกยาเสพติดทั้งหมด (คน)
# *   **จำนวนคดีสมคบ (คดี)** คือ จำนวนคดียาเสพติดข้อหาสมคบคิดทั้งหมด (คดี)
# *   **จำนวนผู้ต้องหาคดีสมคบ (คน)** คือ จำนวนผู้ต้องหาคดียาเสพติดข้อหาสมคบคิดทั้งหมด (คน)
# *   **จำนวนคดี 5 ข้อหาหลัก (คดี)** คือ จำนวนคดียาเสพติด 5 ข้อหาหลัก คือ ครอบครองเพื่อจำหน่าย, จำหน่าย, ผลิต, นำเข้า และส่งออกทั้งหมด (คดี)
# *   **จำนวนผู้ต้องหาคดี 5 ข้อหาหลัก (คน)** คือ จำนวนผู้ต้องหาคดียาเสพติด 5 ข้อหาหลัก คือ ครอบครองเพื่อจำหน่าย, จำหน่าย, ผลิต, นำเข้า และส่งออกทั้งหมด (คดี)

# %%
data_03 = data_03.sort_values(by=['รหัสจังหวัด']) # เรียงข้อมูลตามรหัสจังหวัด 
data_03
# Out:
#     ปีงบประมาณ  ...  จำนวนผู้ต้องหาคดี 5 ข้อหาหลัก (คน)
# 47        2563  ...                                5685
# 53        2563  ...                                2999
# 49        2563  ...                                1448
# 50        2563  ...                                1873
# 51        2563  ...                                1650
# ..         ...  ...                                 ...
# 40        2563  ...                                1346
# 43        2563  ...                                1208
# 42        2563  ...                                1624
# 44        2563  ...                                1161
# 41        2563  ...                                1230
#
# [77 rows x 22 columns]

# %% [markdown]
# ### **ตรวจสอบค่า Missing ของตาราง data_03**

# %%
data_03.isnull() # ตรงไหนเป็นช่องว่างจะขึ้นว่า True ตรงไหนไม่เป็นช่องว่างจะขึ้นว่า False
# Out:
#     ปีงบประมาณ  ...  จำนวนผู้ต้องหาคดี 5 ข้อหาหลัก (คน)
# 47       False  ...                               False
# 53       False  ...                               False
# 49       False  ...                               False
# 50       False  ...                               False
# 51       False  ...                               False
# ..         ...  ...                                 ...
# 40       False  ...                               False
# 43       False  ...                               False
# 42       False  ...                               False
# 44       False  ...                               False
# 41       False  ...                               False
#
# [77 rows x 22 columns]

# %%
data_03.isnull().any() # ดูว่าคอลัมน์ไหนมีค่า missing บ้าง สรุปคือบางคอลัมน์มีค่า  missing  ดังนั้นจะต้องแก้ missing ก่อน
# Out:
# ปีงบประมาณ                                    False
# รหัสจังหวัด                                   False
# จำนวนคดีทั้งหมด (คดี)                         False
# จำนวนผู้ต้องหาทั้งหมด (คน)                    False
# จำนวนคดีเสพ (คดี)                             False
# จำนวนผู้ต้องหาคดีเสพ (คน)                     False
# จำนวนคดีครอบครอง (คดี)                        False
# จำนวนผู้ต้องหาคดีครอบครอง (คน)                False
# จำนวนคดีครอบครองเพื่อจำหน่าย (คดี)            False
# จำนวนผู้ต้องหาคดีครอบครองเพื่อจำหน่าย (คน)    False
# จำนวนคดีจำหน่าย (คดี)                         False
# จำนวนผู้ต้องหาคดีจำหน่าย (คน)                 False
# จำนวนคดีผลิต (คดี)                            False
# จำนวนผู้ต้องหาคดีผลิต (คน)                    False
# จำนวนคดีนำเข้า (คดี)                           True
# จำนวนผู้ต้องหาคดีนำเข้า (คน)                   True
# จำนวนคดีส่งออก (คดี)                          False
# จำนวนผู้ต้องหาคดีส่งออก (คน)                  False
# ...

# %%
data_03_dropped = data_03.dropna() # แก้ค่า missing โดยใช้ .dropna()
data_03_dropped
# Out:
#     ปีงบประมาณ  ...  จำนวนผู้ต้องหาคดี 5 ข้อหาหลัก (คน)
# 47        2563  ...                                5685
# 53        2563  ...                                2999
# 48        2563  ...                                 564
# 60        2563  ...                                 367
# 62        2563  ...                                 651
# 64        2563  ...                                 783
# 66        2563  ...                                2792
# 70        2563  ...                                1427
# 69        2563  ...                                2484
# 72        2563  ...                                3043
# 71        2563  ...                                 855
# 76        2563  ...                                 881
# 74        2563  ...                                2164
# 3         2563  ...                                 913
# 5         2563  ...                                 768
# 0         2563  ...                                1198
# ...

# %%
data_03_dropped.shape # ตรวจสอบขนาดของข้อมูลหลังจากที่ .dropna()
# Out:
# (34, 22)

# %%
data_03.shape # ตรวจสอบขนาดของข้อมูลก่อนที่จะ .dropna()
# Out:
# (77, 22)

# %%
### function หา % ของข้อมูลที่จะหายไปถ้า .dropna()
def loss_data(data):
    before = data.shape[0]
    after = data.dropna().shape[0]
    c = before - after
    print(f'size before drop = {before}')
    print(f'size after drop = {after}')
    print(f'we loss {c*100/before} % of data')

# %%
loss_data(data_03) # จะเห็นได้ว่าหลังจากที่ .dropna() ข้อมูลหายไป 55.84 % ซึ่งเป็นจำนวนมาก ดังนั้นจึงเลือกที่จะแก้ค่า missing ด้วยวิธีอื่น
# Out:
# size before drop = 77
# size after drop = 34
# we loss 55.84415584415584 % of data

# %%
data_03.isnull().any() # ดูว่าคอลัมน์ไหนมีค่า missing บ้าง จะเห็นว่ามีคอลัมน์ที่มีค่า missing อยู่ทั้งหมด 4 คอลัมน์ คือ จำนวนคดีนำเข้า (คดี), จำนวนผู้ต้องหาคดีนำเข้า (คน)
# จำนวนคดีสมคบ (คดี) และ จำนวนผู้ต้องหาคดีสมคบ (คน) ดังนั้นจะทำการแก้ค่า missing ทั้ง 4 คอลัมน์นี้
# Out:
# ปีงบประมาณ                                    False
# รหัสจังหวัด                                   False
# จำนวนคดีทั้งหมด (คดี)                         False
# จำนวนผู้ต้องหาทั้งหมด (คน)                    False
# จำนวนคดีเสพ (คดี)                             False
# จำนวนผู้ต้องหาคดีเสพ (คน)                     False
# จำนวนคดีครอบครอง (คดี)                        False
# จำนวนผู้ต้องหาคดีครอบครอง (คน)                False
# จำนวนคดีครอบครองเพื่อจำหน่าย (คดี)            False
# จำนวนผู้ต้องหาคดีครอบครองเพื่อจำหน่าย (คน)    False
# จำนวนคดีจำหน่าย (คดี)                         False
# จำนวนผู้ต้องหาคดีจำหน่าย (คน)                 False
# จำนวนคดีผลิต (คดี)                            False
# จำนวนผู้ต้องหาคดีผลิต (คน)                    False
# จำนวนคดีนำเข้า (คดี)                           True
# จำนวนผู้ต้องหาคดีนำเข้า (คน)                   True
# จำนวนคดีส่งออก (คดี)                          False
# จำนวนผู้ต้องหาคดีส่งออก (คน)                  False
# ...

# %%
data_03[['จำนวนคดีนำเข้า (คดี)']] = data_03[['จำนวนคดีนำเข้า (คดี)']].fillna('0')  # เติมค่า missing เป็น 0 เนื่องจากในตารางเป็นค่าว่างซึ่งอาจจะแปลว่าไม่มีจำนวนคดียาเสพติดข้อหานำเข้ายาเสพติด

# %%
data_03.isnull().any() # ดูว่าคอลัมน์ไหนมีค่า missing บ้าง จะเห็นว่าคอลัมน์ของ จำนวนคดีนำเข้า (คดี) เป็น False แสดงว่าไม่มีค่า missing
# Out:
# ปีงบประมาณ                                    False
# รหัสจังหวัด                                   False
# จำนวนคดีทั้งหมด (คดี)                         False
# จำนวนผู้ต้องหาทั้งหมด (คน)                    False
# จำนวนคดีเสพ (คดี)                             False
# จำนวนผู้ต้องหาคดีเสพ (คน)                     False
# จำนวนคดีครอบครอง (คดี)                        False
# จำนวนผู้ต้องหาคดีครอบครอง (คน)                False
# จำนวนคดีครอบครองเพื่อจำหน่าย (คดี)            False
# จำนวนผู้ต้องหาคดีครอบครองเพื่อจำหน่าย (คน)    False
# จำนวนคดีจำหน่าย (คดี)                         False
# จำนวนผู้ต้องหาคดีจำหน่าย (คน)                 False
# จำนวนคดีผลิต (คดี)                            False
# จำนวนผู้ต้องหาคดีผลิต (คน)                    False
# จำนวนคดีนำเข้า (คดี)                          False
# จำนวนผู้ต้องหาคดีนำเข้า (คน)                   True
# จำนวนคดีส่งออก (คดี)                          False
# จำนวนผู้ต้องหาคดีส่งออก (คน)                  False
# ...

# %%
data_03[['จำนวนผู้ต้องหาคดีนำเข้า (คน)']] = data_03[['จำนวนผู้ต้องหาคดีนำเข้า (คน)']].fillna('0') # เติมค่า missing เป็น 0 เนื่องจากในตารางเป็นค่าว่างซึ่งอาจจะแปลว่าไม่มีจำนวนผู้ต้องหาคดียาเสพติดข้อหานำเข้ายาเสพติด

# %%
data_03.isnull().any() # ดูว่าคอลัมน์ไหนมีค่า missing บ้าง จะเห็นว่า คอลัมน์ของ จำนวนผู้ต้องหาคดีนำเข้า (คน) เป็น False แสดงว่าไม่มีค่า missing
# Out:
# ปีงบประมาณ                                    False
# รหัสจังหวัด                                   False
# จำนวนคดีทั้งหมด (คดี)                         False
# จำนวนผู้ต้องหาทั้งหมด (คน)                    False
# จำนวนคดีเสพ (คดี)                             False
# จำนวนผู้ต้องหาคดีเสพ (คน)                     False
# จำนวนคดีครอบครอง (คดี)                        False
# จำนวนผู้ต้องหาคดีครอบครอง (คน)                False
# จำนวนคดีครอบครองเพื่อจำหน่าย (คดี)            False
# จำนวนผู้ต้องหาคดีครอบครองเพื่อจำหน่าย (คน)    False
# จำนวนคดีจำหน่าย (คดี)                         False
# จำนวนผู้ต้องหาคดีจำหน่าย (คน)                 False
# จำนวนคดีผลิต (คดี)                            False
# จำนวนผู้ต้องหาคดีผลิต (คน)                    False
# จำนวนคดีนำเข้า (คดี)                          False
# จำนวนผู้ต้องหาคดีนำเข้า (คน)                  False
# จำนวนคดีส่งออก (คดี)                          False
# จำนวนผู้ต้องหาคดีส่งออก (คน)                  False
# ...

# %%
data_03[['จำนวนคดีสมคบ (คดี)']] = data_03[['จำนวนคดีสมคบ (คดี)']].fillna('0')  # เติมค่า missing เป็น 0 เนื่องจากในตารางเป็นค่าว่างซึ่งอาจจะแปลว่าไม่มีจำนวนคดียาเสพติดข้อหาสมคบคิด

# %%
data_03.isnull().any() # ดูว่าคอลัมน์ไหนมีค่า missing บ้าง จะเห็นว่า คอลัมน์ของ จำนวนคดีสมคบ (คดี) เป็น False แสดงว่าไม่มีค่า missing
# Out:
# ปีงบประมาณ                                    False
# รหัสจังหวัด                                   False
# จำนวนคดีทั้งหมด (คดี)                         False
# จำนวนผู้ต้องหาทั้งหมด (คน)                    False
# จำนวนคดีเสพ (คดี)                             False
# จำนวนผู้ต้องหาคดีเสพ (คน)                     False
# จำนวนคดีครอบครอง (คดี)                        False
# จำนวนผู้ต้องหาคดีครอบครอง (คน)                False
# จำนวนคดีครอบครองเพื่อจำหน่าย (คดี)            False
# จำนวนผู้ต้องหาคดีครอบครองเพื่อจำหน่าย (คน)    False
# จำนวนคดีจำหน่าย (คดี)                         False
# จำนวนผู้ต้องหาคดีจำหน่าย (คน)                 False
# จำนวนคดีผลิต (คดี)                            False
# จำนวนผู้ต้องหาคดีผลิต (คน)                    False
# จำนวนคดีนำเข้า (คดี)                          False
# จำนวนผู้ต้องหาคดีนำเข้า (คน)                  False
# จำนวนคดีส่งออก (คดี)                          False
# จำนวนผู้ต้องหาคดีส่งออก (คน)                  False
# ...

# %%
data_03[['จำนวนผู้ต้องหาคดีสมคบ (คน)']] = data_03[['จำนวนผู้ต้องหาคดีสมคบ (คน)']].fillna('0')  # เติมค่า missing เป็น 0 เนื่องจากในตารางเป็นค่าว่างซึ่งอาจจะแปลว่าไม่มีจำนวนผู้ต้องหาคดียาเสพติดข้อหาสมคบคิด

# %%
data_03.isnull().any() # ดูว่าคอลัมน์ไหนมีค่า missing บ้าง จะเห็นว่า คอลัมน์ของ จำนวนผู้ต้องหาคดีสมคบ (คน) เป็น False แสดงว่าไม่มีค่า missing
# Out:
# ปีงบประมาณ                                    False
# รหัสจังหวัด                                   False
# จำนวนคดีทั้งหมด (คดี)                         False
# จำนวนผู้ต้องหาทั้งหมด (คน)                    False
# จำนวนคดีเสพ (คดี)                             False
# จำนวนผู้ต้องหาคดีเสพ (คน)                     False
# จำนวนคดีครอบครอง (คดี)                        False
# จำนวนผู้ต้องหาคดีครอบครอง (คน)                False
# จำนวนคดีครอบครองเพื่อจำหน่าย (คดี)            False
# จำนวนผู้ต้องหาคดีครอบครองเพื่อจำหน่าย (คน)    False
# จำนวนคดีจำหน่าย (คดี)                         False
# จำนวนผู้ต้องหาคดีจำหน่าย (คน)                 False
# จำนวนคดีผลิต (คดี)                            False
# จำนวนผู้ต้องหาคดีผลิต (คน)                    False
# จำนวนคดีนำเข้า (คดี)                          False
# จำนวนผู้ต้องหาคดีนำเข้า (คน)                  False
# จำนวนคดีส่งออก (คดี)                          False
# จำนวนผู้ต้องหาคดีส่งออก (คน)                  False
# ...

# %% [markdown]
# # **ข้อมูลชุดที่ 4 ข้อมูลทั่วไปของจังหวัด**

# %%
data_04 = pd.read_csv(os.path.join(path,'ข้อมูลทั่วไปของจังหวัด.csv')) # ไฟล์ที่เราต้องการ
data_04 # print data ดูว่ามันหน้าตาเป็นยังไง
# Out:
#     ชื่อจังหวัด  ... รายได้เฉลี่ยต่อเดือนของครัวเรือน (บาท)
# 0      เชียงราย  ...                               15056.38
# 1     เชียงใหม่  ...                               20443.21
# 2          น่าน  ...                               18041.55
# 3         พะเยา  ...                               14353.79
# 4          แพร่  ...                               21398.36
# ..          ...  ...                                    ...
# 72      หนองคาย  ...                               20579.85
# 73  หนองบัวลำภู  ...                               18745.43
# 74     อุดรธานี  ...                               25766.53
# 75  อุบลราชธานี  ...                               18397.86
# 76   อำนาจเจริญ  ...                               20320.06
#
# [77 rows x 4 columns]

# %% [markdown]
# ### **คำอธิบายตาราง**
#
#
# *   **ชื่อจังหวัด** คือ ชื่อของจังหวัดทั้งหมดในประเทศไทย
# *   **จำนวนประชากร (คน)** คือ จำนวนของประชากรทั้งหมดในแต่ละจังหวัด (คน)
# *   **พื้นที่ (ตร.กม.)** คือ จำนวนของพื้นที่ทั้งหมดของแต่ละจังหวัด (ตร.กม.)
# *   **รายได้เฉลี่ยต่อเดือนของครัวเรือน (บาท)** คือ รายได้เฉลี่ยต่อเดือนของครัวเรือนในแต่ละจังหวัด (บาท)

# %% [markdown]
# ### **ตรวจสอบค่า Missing ของตาราง data_04**

# %%
data_04.isnull() # ตรงไหนเป็นช่องว่างจะขึ้นว่า True ตรงไหนไม่เป็นช่องว่างจะขึ้นว่า False
# Out:
#     ชื่อจังหวัด  ...  รายได้เฉลี่ยต่อเดือนของครัวเรือน (บาท)
# 0         False  ...                                   False
# 1         False  ...                                   False
# 2         False  ...                                   False
# 3         False  ...                                   False
# 4         False  ...                                   False
# ..          ...  ...                                     ...
# 72        False  ...                                   False
# 73        False  ...                                   False
# 74        False  ...                                   False
# 75        False  ...                                   False
# 76        False  ...                                   False
#
# [77 rows x 4 columns]

# %%
data_04.isnull().any() # ดูว่าคอลัมน์ไหนมีค่า missing บ้างเป็น False แสดงว่าไม่มีค่า missing
# Out:
# ชื่อจังหวัด                               False
# จำนวนประชากร (คน)                         False
# พื้นที่ (ตร.กม.)                          False
# รายได้เฉลี่ยต่อเดือนของครัวเรือน (บาท)    False
# dtype: bool

# %%
data_01.shape # ตรวจสอบขนาดของข้อมูล data_01
# Out:
# (77, 11)

# %%
data_02.shape # ตรวจสอบขนาดของข้อมูล data_02
# Out:
# (77, 12)

# %%
data_03.shape # ตรวจสอบขนาดของข้อมูล data_03
# Out:
# (77, 22)

# %% [markdown]
# #**เชื่อมต่อตาราง**

# %%
# เชื่อมต่อตาราง data_03 (จำนวนคดี ผู้ต้องหาคดียาเสพติด) กับ data_01 (รับเรื่องร้องเรียน/แจ้งเบาะแสยาเสพติด) โดยใช้ รหัสจังหวัด
merge_2table = data_03.merge(data_01,how='left', left_on='รหัสจังหวัด',right_on='รหัสจังหวัด')
merge_2table
# Out:
#     ปีงบประมาณ  ...  เปอร์เซ็นต์การดำเนินการต่อเรื่องร้องเรียนและแจ้งเบาะแสยาเสพติด บุคคล (%)
# 0         2563  ...                                              93.52
# 1         2563  ...                                              97.81
# 2         2563  ...                                             100.00
# 3         2563  ...                                              97.26
# 4         2563  ...                                              99.13
# ..         ...  ...                                                ...
# 72        2563  ...                                             100.00
# 73        2563  ...                                             100.00
# 74        2563  ...                                             100.00
# 75        2563  ...                                             100.00
# 76        2563  ...                                             100.00
#
# [77 rows x 32 columns]

# %% [markdown]
# ### **ตรวจสอบค่า Missing ของตาราง 2 ตารางที่เชื่อมต่อกันแล้ว**

# %%
merge_2table.isnull() # ตรงไหนเป็นช่องว่างจะขึ้นว่า True ตรงไหนไม่เป็นช่องว่างจะขึ้นว่า False
# Out:
#     ปีงบประมาณ  ...  เปอร์เซ็นต์การดำเนินการต่อเรื่องร้องเรียนและแจ้งเบาะแสยาเสพติด บุคคล (%)
# 0        False  ...                                              False
# 1        False  ...                                              False
# 2        False  ...                                              False
# 3        False  ...                                              False
# 4        False  ...                                              False
# ..         ...  ...                                                ...
# 72       False  ...                                              False
# 73       False  ...                                              False
# 74       False  ...                                              False
# 75       False  ...                                              False
# 76       False  ...                                              False
#
# [77 rows x 32 columns]

# %%
merge_2table.isnull().any() # ดูว่าคอลัมน์ไหนมีค่า missing บ้าง สรุปคือไม่มีคอลัมน์ไหนที่มีค่า missing
# Out:
# ปีงบประมาณ                                                                    False
# รหัสจังหวัด                                                                   False
# จำนวนคดีทั้งหมด (คดี)                                                         False
# จำนวนผู้ต้องหาทั้งหมด (คน)                                                    False
# จำนวนคดีเสพ (คดี)                                                             False
# จำนวนผู้ต้องหาคดีเสพ (คน)                                                     False
# จำนวนคดีครอบครอง (คดี)                                                        False
# จำนวนผู้ต้องหาคดีครอบครอง (คน)                                                False
# จำนวนคดีครอบครองเพื่อจำหน่าย (คดี)                                            False
# จำนวนผู้ต้องหาคดีครอบครองเพื่อจำหน่าย (คน)                                    False
# จำนวนคดีจำหน่าย (คดี)                                                         False
# ...

# %%
# เชื่อมต่อตาราง data_03 (จำนวนคดี ผู้ต้องหาคดียาเสพติด) กับ data_01 (รับเรื่องร้องเรียน/แจ้งเบาะแสยาเสพติด) กับ data_02 (ปริมาณของกลางยาเสพติด) โดยใช้ รหัสจังหวัด
merge_3table = merge_2table.merge(data_02,how='left', left_on='รหัสจังหวัด',right_on='รหัสจังหวัด')
merge_3table
# Out:
#     ปีงบประมาณ  ...  ปริมาณของกลางยาเสพติดที่พบมากที่สุด (กิโลกรัม)
# 0         2563  ...                                      2755.81611
# 1         2563  ...                                       332.85821
# 2         2563  ...                                       626.33734
# 3         2563  ...                                       981.02860
# 4         2563  ...                                       932.65946
# ..         ...  ...                                             ...
# 72        2563  ...                                      1772.45500
# 73        2563  ...                                      1242.31250
# 74        2563  ...                                      5950.30800
# 75        2563  ...                                      4043.89700
# 76        2563  ...                                      5569.70900
#
# [77 rows x 43 columns]

# %% [markdown]
# ### **ตรวจสอบค่า Missing ของตาราง 3 ตารางที่เชื่อมต่อกันแล้ว**

# %%
merge_3table.isnull() # ตรงไหนเป็นช่องว่างจะขึ้นว่า True ตรงไหนไม่เป็นช่องว่างจะขึ้นว่า False
# Out:
#     ปีงบประมาณ  ...  ปริมาณของกลางยาเสพติดที่พบมากที่สุด (กิโลกรัม)
# 0        False  ...                                           False
# 1        False  ...                                           False
# 2        False  ...                                           False
# 3        False  ...                                           False
# 4        False  ...                                           False
# ..         ...  ...                                             ...
# 72       False  ...                                           False
# 73       False  ...                                           False
# 74       False  ...                                           False
# 75       False  ...                                           False
# 76       False  ...                                           False
#
# [77 rows x 43 columns]

# %%
merge_3table.isnull().any()  # ดูว่าคอลัมน์ไหนมีค่า missing บ้าง สรุปคือไม่มีคอลัมน์ไหนที่มีค่า missing
# Out:
# ปีงบประมาณ                                                                    False
# รหัสจังหวัด                                                                   False
# จำนวนคดีทั้งหมด (คดี)                                                         False
# จำนวนผู้ต้องหาทั้งหมด (คน)                                                    False
# จำนวนคดีเสพ (คดี)                                                             False
# จำนวนผู้ต้องหาคดีเสพ (คน)                                                     False
# จำนวนคดีครอบครอง (คดี)                                                        False
# จำนวนผู้ต้องหาคดีครอบครอง (คน)                                                False
# จำนวนคดีครอบครองเพื่อจำหน่าย (คดี)                                            False
# จำนวนผู้ต้องหาคดีครอบครองเพื่อจำหน่าย (คน)                                    False
# จำนวนคดีจำหน่าย (คดี)                                                         False
# ...

# %%
# เชื่อมต่อตาราง data_03 (จำนวนคดี ผู้ต้องหาคดียาเสพติด) กับ data_01 (รับเรื่องร้องเรียน/แจ้งเบาะแสยาเสพติด) กับ data_02 (ปริมาณของกลางยาเสพติด) กับ data_04 ข้อมูลทั่วไปของจังหวัด โดยใช้ ชื่อจังหวัด
merge_4table = merge_3table.merge(data_04,how='left', left_on='ชื่อจังหวัด',right_on='ชื่อจังหวัด')
merge_4table
# Out:
#     ปีงบประมาณ  ...  รายได้เฉลี่ยต่อเดือนของครัวเรือน (บาท)
# 0         2563  ...                                39459.36
# 1         2563  ...                                24729.42
# 2         2563  ...                                37502.22
# 3         2563  ...                                46977.74
# 4         2563  ...                                30589.95
# ..         ...  ...                                     ...
# 72        2563  ...                                26004.22
# 73        2563  ...                                20084.91
# 74        2563  ...                                22903.84
# 75        2563  ...                                16588.15
# 76        2563  ...                                17716.50
#
# [77 rows x 46 columns]

# %%
merge_4table.isnull() # ตรงไหนเป็นช่องว่างจะขึ้นว่า True ตรงไหนไม่เป็นช่องว่างจะขึ้นว่า False
# Out:
#     ปีงบประมาณ  ...  รายได้เฉลี่ยต่อเดือนของครัวเรือน (บาท)
# 0        False  ...                                   False
# 1        False  ...                                   False
# 2        False  ...                                   False
# 3        False  ...                                   False
# 4        False  ...                                   False
# ..         ...  ...                                     ...
# 72       False  ...                                   False
# 73       False  ...                                   False
# 74       False  ...                                   False
# 75       False  ...                                   False
# 76       False  ...                                   False
#
# [77 rows x 46 columns]

# %%
merge_4table.isnull().any()  # ดูว่าคอลัมน์ไหนมีค่า missing บ้าง สรุปคือไม่มีคอลัมน์ไหนที่มีค่า missing
# Out:
# ปีงบประมาณ                                                                    False
# รหัสจังหวัด                                                                   False
# จำนวนคดีทั้งหมด (คดี)                                                         False
# จำนวนผู้ต้องหาทั้งหมด (คน)                                                    False
# จำนวนคดีเสพ (คดี)                                                             False
# จำนวนผู้ต้องหาคดีเสพ (คน)                                                     False
# จำนวนคดีครอบครอง (คดี)                                                        False
# จำนวนผู้ต้องหาคดีครอบครอง (คน)                                                False
# จำนวนคดีครอบครองเพื่อจำหน่าย (คดี)                                            False
# จำนวนผู้ต้องหาคดีครอบครองเพื่อจำหน่าย (คน)                                    False
# จำนวนคดีจำหน่าย (คดี)                                                         False
# ...

# %% [markdown]
# # **Classification**

# %% [markdown]
# ### **ปัญหา**
# คือ เพื่อทำนายชนิดของยาเสพติด โดยใช้จำนวนประชากร, พื้นที่, รายได้เฉลี่ยต่อเดือนของครัวเรือน,จำนวนเรื่องร้องเรียน/แจ้งเบาะแสยาเสพติด,ปริมาณของกลางยาเสพติดและจำนวนคดีผู้ต้องหาคดียาเสพติด

# %% [markdown]
# ### **เลือกคอลัมน์ที่ต้องการนำมาใช้งาน**

# %%
data = merge_4table[['ชื่อจังหวัด','จำนวนประชากร (คน) ','พื้นที่ (ตร.กม.)','รายได้เฉลี่ยต่อเดือนของครัวเรือน (บาท)','ปริมาณของกลางยาเสพติดทั้งหมด (กิโลกรัม)','เรื่องร้องเรียนและแจ้งเบาะแสยาเสพติดทั้งหมด (เรื่อง)','จำนวนคดีทั้งหมด (คดี)','ชนิดของกลางยาเสพติด']]
data
# Out:
#         ชื่อจังหวัด  ... ชนิดของกลางยาเสพติด
# 0     กรุงเทพมหานคร  ...             กระท่อม
# 1       สมุทรปราการ  ...             กระท่อม
# 2           นนทบุรี  ...             กระท่อม
# 3          ปทุมธานี  ...             กระท่อม
# 4   พระนครศรีอยุธยา  ...             กระท่อม
# ..              ...  ...                 ...
# 72             ตรัง  ...             กระท่อม
# 73           พัทลุง  ...             กระท่อม
# 74          ปัตตานี  ...             กระท่อม
# 75             ยะลา  ...             กระท่อม
# 76         นราธิวาส  ...             กระท่อม
#
# [77 rows x 8 columns]

# %%
data.shape
# Out:
# (77, 8)

# %%
data.isnull().any()  # ดูว่าคอลัมน์ไหนมีค่า missing บ้าง สรุปคือไม่มีคอลัมน์ไหนที่มีค่า missing
# Out:
# ชื่อจังหวัด                                             False
# จำนวนประชากร (คน)                                       False
# พื้นที่ (ตร.กม.)                                        False
# รายได้เฉลี่ยต่อเดือนของครัวเรือน (บาท)                  False
# ปริมาณของกลางยาเสพติดทั้งหมด (กิโลกรัม)                 False
# เรื่องร้องเรียนและแจ้งเบาะแสยาเสพติดทั้งหมด (เรื่อง)    False
# จำนวนคดีทั้งหมด (คดี)                                   False
# ชนิดของกลางยาเสพติด                                     False
# dtype: bool

# %%
# กำหนด X และ y
X = data[['จำนวนประชากร (คน) ','พื้นที่ (ตร.กม.)','รายได้เฉลี่ยต่อเดือนของครัวเรือน (บาท)','ปริมาณของกลางยาเสพติดทั้งหมด (กิโลกรัม)','เรื่องร้องเรียนและแจ้งเบาะแสยาเสพติดทั้งหมด (เรื่อง)','จำนวนคดีทั้งหมด (คดี)']]
y = data[['ชนิดของกลางยาเสพติด']]

# %%
X.dtypes # ตรวจสอบชนิดของข้อมูล พบว่าข้อมูลของจำนวนประชากรและข้อมูลของพื้นที่ของแต่ละจังหวัดเป็น Object และจำนวนเรื่องร้องเรียนและแจ้งเบาะแสยาเสพติดทั้งหมด (เรื่อง) 
# และจำนวนคดีทั้งหมด (คดี) ชนิดของข้อมูลเป็น int จึงทำการเปลี่ยนให้เป็น Float เพื่อให้ข้อมูลเป็นข้อมูลชนิดเดียวกันทั้งหมด
# Out:
# จำนวนประชากร (คน)                                        object
# พื้นที่ (ตร.กม.)                                         object
# รายได้เฉลี่ยต่อเดือนของครัวเรือน (บาท)                  float64
# ปริมาณของกลางยาเสพติดทั้งหมด (กิโลกรัม)                 float64
# เรื่องร้องเรียนและแจ้งเบาะแสยาเสพติดทั้งหมด (เรื่อง)      int64
# จำนวนคดีทั้งหมด (คดี)                                     int64
# dtype: object

# %%
import re
X = X.replace('[^\d.]','', regex=True).astype(float) # เปลี่ยนชนิดของข้อมูล
X
# Out:
#     จำนวนประชากร (คน)   ...  จำนวนคดีทั้งหมด (คดี)
# 0            5682415.0  ...                21550.0
# 1            1310766.0  ...                 6990.0
# 2            1229735.0  ...                 3432.0
# 3            1129115.0  ...                 4235.0
# 4             808360.0  ...                 4199.0
# ..                 ...  ...                    ...
# 72            643072.0  ...                 3688.0
# 73            524857.0  ...                 2430.0
# 74            709796.0  ...                 4563.0
# 75            527295.0  ...                 3326.0
# 76            796239.0  ...                 4231.0
#
# [77 rows x 6 columns]

# %%
y.dtypes  # ตรวจสอบชนิดของข้อมูล
# Out:
# ชนิดของกลางยาเสพติด    object
# dtype: object

# %% [markdown]
# **Train Model**

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# **Train - Test**

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=6)

# %%
X_train.shape
# Out:
# (38, 6)

# %% [markdown]
# **Train - Validation**

# %%
X_train2, X_val, y_train2, y_val = train_test_split(X_train, y_train, test_size=0.3, random_state=6)

# %%
X_train2.shape
# Out:
# (26, 6)

# %% [markdown]
# ## **Decision Tree**

# %% [markdown]
# **import**

# %%
from sklearn.tree import DecisionTreeClassifier # เรียกใช้อัลกอริทึมที่เราต้องการ

# %%
from sklearn.metrics import accuracy_score

# %% [markdown]
# **Mytree 1**

# %%
# Define
mytree1 = DecisionTreeClassifier(random_state=1) # กำหนดพารามิเตอร์ให้กับ model
# Train
mytree1.fit(X_train2,y_train2) # ฝึกสอนตัวแบบ
# Test
mytree1_result = mytree1.predict(X_val)
accuracy_score(y_val,mytree1_result) # นั่นคือ มีความแม่นยำ 41.67 %
# Out:
# 0.3333333333333333

# %% [markdown]
# **Mytree 2**

# %%
# Define
mytree2 = DecisionTreeClassifier(max_leaf_nodes=50,criterion='gini')
#Train
mytree2.fit(X_train2,y_train2)
#Test
mytree2_result = mytree2.predict(X_val)
accuracy_score(y_val,mytree2_result) # นั่นคือ มีความแม่นยำ 41.67 %
# Out:
# 0.5

# %% [markdown]
# **Mytree 3**

# %%
# Define
mytree3 = DecisionTreeClassifier(criterion='entropy', splitter='random',random_state=1) # กำหนดพารามิเตอร์ให้กับ model
#Train
mytree3.fit(X_train2,y_train2)
#Test
mytree3_result = mytree3.predict(X_val)
accuracy_score(y_val,mytree3_result) # นั่นคือ มีความแม่นยำ 58.33 %
# Out:
# 0.4166666666666667

# %% [markdown]
# **plot tree**

# %%
from sklearn.tree import plot_tree

# %%
plot_tree(mytree3) # ลอง plot
# Out:
# [Text(177.24705882352941, 201.90857142857143, 'X[0] <= 1093022.123\nentropy = 1.489\nsamples = 26\nvalue = [16, 2, 6, 2]'),
#  Text(98.47058823529412, 170.84571428571428, 'X[0] <= 581998.995\nentropy = 1.076\nsamples = 20\nvalue = [14, 1, 5, 0]'),
#  Text(78.7764705882353, 139.78285714285715, 'X[2] <= 21284.58\nentropy = 1.231\nsamples = 15\nvalue = [9, 1, 5, 0]'),
#  Text(39.38823529411765, 108.72, 'X[3] <= 1193.985\nentropy = 1.252\nsamples = 6\nvalue = [1, 1, 4, 0]'),
#  Text(19.694117647058825, 77.65714285714284, 'entropy = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0]'),
#  Text(59.082352941176474, 77.65714285714284, 'X[0] <= 457703.467\nentropy = 1.585\nsamples = 3\nvalue = [1, 1, 1, 0]'),
#  Text(39.38823529411765, 46.59428571428572, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]'),
#  Text(78.7764705882353, 46.59428571428572, 'X[0] <= 522086.337\nentropy = 1.0\nsamples = 2\nvalue = [1, 0, 1, 0]'),
# ...

# %% [markdown]
# ## **KNN**

# %% [markdown]
# **Import**

# %%
from sklearn.neighbors import KNeighborsClassifier # เรียกใช้อัลกอริทึมที่เราต้องการ

# %% [markdown]
# **KNN 1**

# %%
# Define
neigh1 = KNeighborsClassifier(n_neighbors=3, weights='uniform') # ถามเพื่อนบ้านที่ใกล้สุด 3 คนและเชื่อทุกๆคนเท่ากัน
#Train
neigh1.fit(X_train2,y_train2)
#Test
KNN1_result = neigh1.predict(X_val)
accuracy_score(y_val, KNN1_result) # นั่นคือ มีความแม่นยำ 33.33 %
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/neighbors/_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# 0.3333333333333333

# %% [markdown]
# **KNN 2**

# %%
# Define
neigh2 = KNeighborsClassifier(n_neighbors=3, weights='distance') # ถามเพื่อนบ้าน 3 คน และเชื่อเพื่อนบ้านที่ใกล้ที่สุดมากกว่าเพื่อนบ้านที่ไกล
#Train
neigh2.fit(X_train2,y_train2)
#Test
KNN2_result = neigh2.predict(X_val)
accuracy_score(y_val, KNN2_result) # นั่นคือ มีความแม่นยำ 41.67 %
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/neighbors/_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# 0.4166666666666667

# %% [markdown]
# **KNN 3**

# %%
# Define
neigh3 = KNeighborsClassifier(n_neighbors=1) # เลือกเพื่อนบ้านที่ใกล้ที่สุดแค่คนเดียว
#Train
neigh3.fit(X_train2,y_train2)
#Test
KNN3_result = neigh3.predict(X_val)
accuracy_score(y_val, KNN3_result) # นั่นคือ มีความแม่นยำ 41.67 %
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/neighbors/_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# 0.4166666666666667

# %% [markdown]
# ## **Neural Network**

# %% [markdown]
# **Import**

# %%
from sklearn.neural_network import MLPClassifier # เรียกใช้อัลกอริทึมที่เราต้องการ

# %% [markdown]
# **ANN 1**

# %%
# Define
perceptron1 = MLPClassifier(random_state=6, max_iter=50,hidden_layer_sizes=1,learning_rate_init=0.01)  # กำหนดพารามิเตอร์ให้กับ model
#Train
perceptron1.fit(X_train2,y_train2) 
#Test
perceptron1_result = perceptron1.predict(X_val)
accuracy_score(y_val,perceptron1_result) # นั่นคือ มีความแม่นยำ 41.67 %
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:1109: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 0.4166666666666667

# %% [markdown]
# **ANN2**

# %%
perceptron2 = MLPClassifier(random_state=6, max_iter=2000,hidden_layer_sizes=10,learning_rate_init=0.005)
#Train
perceptron2.fit(X_train2,y_train2)
#Test
perceptron2_result = perceptron2.predict(X_val)
accuracy_score(y_val,perceptron2_result) # นั่นคือ มีความแม่นยำ 41.67 %
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:1109: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 0.08333333333333333

# %% [markdown]
# **ANN3**

# %%
perceptron3 = MLPClassifier(random_state=6, max_iter=20000,hidden_layer_sizes=10,learning_rate_init=0.001)
#Train
perceptron3.fit(X_train2,y_train2)
#Test
perceptron3_result = perceptron3.predict(X_val)
accuracy_score(y_val,perceptron3_result) # นั่นคือ มีความแม่นยำ 16.67 %
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:1109: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 0.08333333333333333

# %% [markdown]
# **เปรียบเทียบความแม่นยำของการทำ classification ด้วย model ต่างๆ**

# %%
# กราฟเปรียบเทียบความแม่นยำของการวัดผลการทำ classification ด้วย model ต่างๆ 
from matplotlib import pyplot as plt
labels = ['Decision Tree (mytree3)','KNN (KNN2)','ANN (ANN2)']
accuracy = [accuracy_score(y_val,mytree3_result),accuracy_score(y_val, KNN2_result),accuracy_score(y_val,perceptron2_result)]
#plot
plt.bar(labels,accuracy)
plt.ylabel('Accuracy Score')
plt.xlabel('Model')
plt.title('Compare Accuracy Score')
plt.legend();
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# **พบว่า** จากการวัดผลการทำ classification ด้วย model ต่างๆ Model Decision Tree(Mytree 3), KNN(KNN 2 , KNN 3 ) และ ANN (ANN 2) มีค่า Accuracy มากที่สุด คือ 0.4166666666666667 นั่นคือมีความแม่นยำ 41.67 %

# %% [markdown]
# # **Evaluation**

# %% [markdown]
# ### **Retain & Evaluation**

# %% [markdown]
# **เนื่องจา่กค่า Accuracy ของ Mytree 3, KNN 2 , KNN 3 และ ANN 2 มีค่าเท่ากัน คือ 0.4166666666666667 จึงทำการ Retrain ทั้ง 4 ตัวแบบเพื่อหาตัวแบบที่เหมาะสมที่สุด**

# %%
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix  # เรียกใช้อัลกอริทึมที่เราต้องการ

# %% [markdown]
# เลือกตัวแบบ **mytree3** แล้วนำมา Train ใหม่

# %%
# Define
mytree3_final = DecisionTreeClassifier(criterion='entropy', splitter='random',random_state=1) # กำหนดพารามิเตอร์ให้กับ model
#Train
mytree3_final.fit(X_train,y_train)
#Test
mytree3final_result = mytree3_final.predict(X_test)
accuracy_score(y_test,mytree3final_result) # นั่นคือ มีความแม่นยำ 53.85 %
# Out:
# 0.5384615384615384

# %% [markdown]
# เลือกตัวแบบ **KNN 2** แล้วนำมา Train ใหม่

# %%
# Define
neigh2_final = KNeighborsClassifier(n_neighbors=3, weights='distance') # ถามเพื่อนบ้าน 3 คน และเชื่อเพื่อนบ้านที่ใกล้ที่สุดมากกว่าเพื่อนบ้านที่ไกล
#Train
neigh2_final.fit(X_train,y_train)
#Test
KNN2final_result = neigh2_final.predict(X_test)
accuracy_score(y_test, KNN2final_result) # นั่นคือ มีความแม่นยำ 28.21 %
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/neighbors/_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# 0.28205128205128205

# %% [markdown]
# เลือกตัวแบบ **KNN 3**แล้วนำมา Train ใหม่

# %%
# Define
neigh3_final = KNeighborsClassifier(n_neighbors=1) # เลือกเพื่อนบ้านที่ใกล้ที่สุดแค่คนเดียว
#Train
neigh3_final.fit(X_train,y_train)
#Test
KNN3final_result = neigh3_final.predict(X_test)
accuracy_score(y_test, KNN3final_result) # นั่นคือ มีความแม่นยำ 35.90 %
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/neighbors/_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# 0.358974358974359

# %% [markdown]
# เลือกตัวแบบ **ANN 2**แล้วนำมา Train ใหม่

# %%
#Define
perceptron2_final = MLPClassifier(random_state=6, max_iter=2000,hidden_layer_sizes=10,learning_rate_init=0.005)
#Train
perceptron2_final.fit(X_train,y_train) 
#Test
perceptron2final_result = perceptron2_final.predict(X_test)
accuracy_score(y_test,perceptron2final_result) # นั่นคือ มีความแม่นยำ 71.79 %
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:1109: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 0.02564102564102564

# %% [markdown]
# **สรุปผล** จากการ Retrain ของทั้ง 4 ตัวแบบ พบว่า ค่า accuracy ของ mytree3 มีค่าเท่ากับ 0.5384615384615384, ค่า accuracy ของ KNN 2 มีค่าเท่ากับ 0.28205128205128205, ค่า accuracy ของ KNN 3 มีค่าเท่ากับ 0.358974358974359 และค่า accuracy ของ ANN 2 มีค่าเท่ากับ 0.717948717948718
#
# **ดังนั้น เมื่อนำทั้ง 4 ค่ามาเทียบกันพบว่า ค่า accuracy ของ ANN 2 มีค่ามากที่สุด นั่นคือมีความแม่นยำ 71.79 % จึงเลือกตัวแบบ ANN 2 เพราะมีความเหมาะสมและมีความแม่นยำที่สุด**

# %%
confusion_matrix(y_test,perceptron2final_result)
# Out:
# array([[ 0, 12,  0,  0],
#        [ 0,  1,  0,  0],
#        [ 0, 23,  0,  0],
#        [ 0,  3,  0,  0]])

# %%
ref = classification_report(y_test,perceptron2final_result)
print(ref)
# Out:
#               precision    recall  f1-score   support
#
#      กระท่อม       0.00      0.00      0.00        12
#    กัญชาแห้ง       0.03      1.00      0.05         1
#        ยาบ้า       0.00      0.00      0.00        23
#         ไอซ์       0.00      0.00      0.00         3
#
#     accuracy                           0.03        39
#    macro avg       0.01      0.25      0.01        39
# weighted avg       0.00      0.03      0.00        39
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %% [markdown]
# # **Data_Visualization**

# %% [markdown]
# **ดูการกระจายของชนิดของกลางยาเสพติดที่พบมากที่สุดในแต่ละจังหวัด ว่ามีกี่จังหวัดที่พบของกลางยาเสพติดแต่ละชนิดบ้าง**

# %%
# พิจารณาการกระจายของชนิดของกลางยาเสพติดที่พบมากที่สุดในแต่ละจังหวัด ว่ามีกี่จังหวัดที่พบของกลางยาเสพติดแต่ละชนิดบ้าง
data_02.groupby(['ชนิดของกลางยาเสพติด']).count().iloc[:,1]
# Out:
# ชนิดของกลางยาเสพติด
# กระท่อม      33
# กัญชาแห้ง     4
# ยาบ้า        34
# ไอซ์          6
# Name: จังหวัด, dtype: int64

# %% [markdown]
# **พบว่า** ชนิดของกลางยาเสพติดที่พบมากที่สุด คือ ยาบ้า พบทั้งหมด 34 จังหวัด รองลงมาคือ กระท่อม พบทั้งหมด 33 จังหวัด ไอซ์ พบทั้งหมด 6 จังหวัด และกัญชาแห้งพบทั้งหมด 4 จังหวัด

# %%
# จำนวนของจังหวัดที่พบของกลางยาเสพติดที่พบมากที่สุดแต่ละชนิด
กระท่อม = data_02.groupby(['ชนิดของกลางยาเสพติด']).count().iloc[0,1] # จำนวนของจังหวัดที่พบของกลางยาเสพติดที่พบมากที่สุด คือ กระท่อม
กัญชาแห้ง = data_02.groupby(['ชนิดของกลางยาเสพติด']).count().iloc[1,1] # จำนวนของจังหวัดที่พบของกลางยาเสพติดที่พบมากที่สุด คือ กัญชาแห้ง
ยาบ้า = data_02.groupby(['ชนิดของกลางยาเสพติด']).count().iloc[2,1] # จำนวนของจังหวัดที่พบของกลางยาเสพติดที่พบมากที่สุด คือ ยาบ้า
ไอซ์ = data_02.groupby(['ชนิดของกลางยาเสพติด']).count().iloc[3,1] # จำนวนของจังหวัดที่พบของกลางยาเสพติดที่พบมากที่สุด คือ ไอซ์

# %%
# ทำการติดตั้ง font ภาษาไทยเพื่อนำมาใช้ในการ plot กราฟ
import matplotlib as matplotlib # ทำการเช็ค version ของตัว library ดู ซึ่งเข้าใจว่าต้องเป็น version 3.2 ขึ้นไปเท่านั้นถึงจะใช้ได้ ถ้า version ต่ำกว่านี้ก็อาจจะต้องทำการอัพเดต version ก่อน
matplotlib.__version__
# Out:
# '3.2.2'

# %%
# ทำการดาวน์โหลด font ในที่นี้ก็จะใช้โค้ดด้านล่างนี้ โหลด font ที่ชื่อว่า thsarabunnew
# !wget -q https://github.com/Phonbopit/sarabun-webfont/raw/master/fonts/thsarabunnew-webfont.ttf

# %%
matplotlib.font_manager.fontManager.addfont('thsarabunnew-webfont.ttf')  #เพื่ม font ที่เรา download มาเข้าไปใน font manager ของ matplotlib พร้อมกับเซ็ตค่า font ที่จะใช้งานแสดงบนกราฟที่เราจะพล็อต
matplotlib.rc('font', family='TH Sarabun New')

# %%
# กราฟการกระจายชนิดของกลางยาเสพติดที่พบมากที่สุดในแต่ละจังหวัด ว่ามีกี่จังหวัดที่พบของกลางยาเสพติดแต่ละชนิดบ้าง
from matplotlib import pyplot as plt # เรียกใช้อัลกอริทึมที่ต้องการ
ชนิดของกลางยาเสพติดที่พบมากที่สุด = ['กัญชาแห้ง','ไอซ์','ยาบ้า','กระท่อม']
จำนวนจังหวัดที่พบ = [กัญชาแห้ง,ไอซ์,ยาบ้า,กระท่อม]
#plot
plt.bar(ชนิดของกลางยาเสพติดที่พบมากที่สุด,จำนวนจังหวัดที่พบ)
plt.ylabel('จำนวนจังหวัดที่พบ')
plt.xlabel('ชนิดของกลางยาเสพติดที่พบมากที่สุด')
plt.title('กราฟการกระจายชนิดของกลางยาเสพติดที่พบมากที่สุดในแต่ละจังหวัด')
plt.show();

# %% [markdown]
# **คำอธิบาย** : จากกราฟการกระจายชนิดของกลางยาเสพติดที่พบมากที่สุดในแต่ละจังหวัด ว่ามีกี่จังหวัดที่พบของกลางยาเสพติดแต่ละชนิดบ้าง พบว่า ชนิดของกลางยาเสพติดที่พบมากที่สุด คือ ยาบ้า พบทั้งหมด 34 จังหวัด รองลงมาคือ กระท่อม พบทั้งหมด 33 จังหวัด ไอซ์ พบทั้งหมด 6 จังหวัด และกัญชาแห้งพบทั้งหมด 4 จังหวัด ตามลำดับ

# %% [markdown]
# **ผลการทำนายชนิดของยาเสพติดที่ได้จาก model**

# %%
perceptron2final_result # ดูค่าของ y หรือผลการทำนายชนิดของยาเสพติดที่ได้จาก model ผลลัพธ์ที่ได้เป็นดังนี้
# Out:
# array(['กัญชาแห้ง', 'กัญชาแห้ง', 'กัญชาแห้ง', 'กัญชาแห้ง', 'กัญชาแห้ง',
#        'กัญชาแห้ง', 'กัญชาแห้ง', 'กัญชาแห้ง', 'กัญชาแห้ง', 'กัญชาแห้ง',
#        'กัญชาแห้ง', 'กัญชาแห้ง', 'กัญชาแห้ง', 'กัญชาแห้ง', 'กัญชาแห้ง',
#        'กัญชาแห้ง', 'กัญชาแห้ง', 'กัญชาแห้ง', 'กัญชาแห้ง', 'กัญชาแห้ง',
#        'กัญชาแห้ง', 'กัญชาแห้ง', 'กัญชาแห้ง', 'กัญชาแห้ง', 'กัญชาแห้ง',
#        'กัญชาแห้ง', 'กัญชาแห้ง', 'กัญชาแห้ง', 'กัญชาแห้ง', 'กัญชาแห้ง',
#        'กัญชาแห้ง', 'กัญชาแห้ง', 'กัญชาแห้ง', 'กัญชาแห้ง', 'กัญชาแห้ง',
#        'กัญชาแห้ง', 'กัญชาแห้ง', 'กัญชาแห้ง', 'กัญชาแห้ง'], dtype='<U9')

# %%
X_test # ดูค่าของ X หรือข้อมูลที่เรานำมาใช้ในการทำนายหาชนิดของยาเสพติด
# Out:
#     จำนวนประชากร (คน)   ...  จำนวนคดีทั้งหมด (คดี)
# 29           1544786.0  ...                 5175.0
# 34            982578.0  ...                 4407.0
# 23            539542.0  ...                 3035.0
# 58            911492.0  ...                 3675.0
# 56            839776.0  ...                 3191.0
# 66            402017.0  ...                 6645.0
# 47           1065334.0  ...                 2772.0
# 17            485632.0  ...                 2499.0
# 0            5682415.0  ...                21550.0
# 59            491887.0  ...                 1905.0
# 38           1640479.0  ...                11197.0
# 46            242742.0  ...                  612.0
# 40            761949.0  ...                 4343.0
# 13            220921.0  ...                 1443.0
# 39            404560.0  ...                 3021.0
# 64            469769.0  ...                 4772.0
# 20           1381761.0  ...                 2269.0
# ...

# %%
from matplotlib import pyplot as plt # เรียกใช้อัลกอริทึมที่เราต้องการ

# %%
# กราฟผลการทำนายชนิดของยาเสพติด โดยใช้จำนวนประชากร, พื้นที่, รายได้เฉลี่ยต่อเดือนของครัวเรือน,จำนวนเรื่องร้องเรียน/แจ้งเบาะแสยาเสพติด,ปริมาณของกลางยาเสพติดและจำนวนคดีผู้ต้องหาคดียาเสพติด
plt.plot(X_test['จำนวนประชากร (คน) '],perceptron2final_result,'Pb',alpha =0.2) 
plt.plot(X_test['พื้นที่ (ตร.กม.)'],perceptron2final_result,'Pr',alpha = 0.8) 
plt.plot(X_test['รายได้เฉลี่ยต่อเดือนของครัวเรือน (บาท)'],perceptron2final_result,'Pg',alpha =0.1)
plt.plot(X_test['ปริมาณของกลางยาเสพติดทั้งหมด (กิโลกรัม)'],perceptron2final_result,'Pm',alpha =0.8)
plt.plot(X_test['เรื่องร้องเรียนและแจ้งเบาะแสยาเสพติดทั้งหมด (เรื่อง)'],perceptron2final_result,'Py',alpha =0.8)
plt.plot(X_test['จำนวนคดีทั้งหมด (คดี)'],perceptron2final_result,'Pc',alpha =0.3)
plt.xlabel('จำนวน')
plt.ylabel('ชนิดของยาเสพติด')
plt.title('ผลการทำนายชนิดของยาเสพติด โดยใช้จำนวนประชากร, พื้นที่, รายได้เฉลี่ยต่อเดือนของครัวเรือน,จำนวนเรื่องร้องเรียน/แจ้งเบาะแสยาเสพติด,ปริมาณของกลางยาเสพติดและจำนวนคดีผู้ต้องหาคดียาเสพติด')
plt.show();

# %%
# กราฟผลการทำนายชนิดของยาเสพติดโดยใช้จำนวนประชากร (คน)
plt.plot(X_test['จำนวนประชากร (คน) '],perceptron2final_result,'Pb') 
plt.xlabel('จำนวนประชากร (คน)')
plt.ylabel('ชนิดของยาเสพติด')
plt.title('ผลการทำนายชนิดของยาเสพติดโดยใช้จำนวนประชากร (คน)')
plt.show();

# %% [markdown]
# **คำอธิบาย** : จากกราฟผลการทำนายชนิดของยาเสพติดโดยใช้จำนวนประชากร (คน) พบว่า ถ้าสมมติว่าจังหวัดนั้นมีจำนวนประชากรประมาณ 150,000 คน ชนิดของยาเสพติดที่พบมากที่สุดก็คือ ยาบ้า , สมมติว่าจังหวัดนั้นมีจำนวนประชากรประมาณ 160,000 คน ชนิดของยาเสพติดที่พบมากที่สุดก็คือ ไอซ์ และสมมติว่าจังหวัดนั้นมีจำนวนประชากรประมาณ 580,000 คน ชนิดของยาเสพติดที่พบมากที่สุดก็คือ กระท่อม เป็นต้น

# %%
# กราฟผลการทำนายชนิดของยาเสพติดโดยใช้พื้นที่ (ตร.กม.)
plt.plot(X_test['พื้นที่ (ตร.กม.)'],perceptron2final_result,'Pm') 
plt.xlabel('พื้นที่ (ตร.กม.)')
plt.ylabel('ชนิดของยาเสพติด')
plt.title('ผลการทำนายชนิดของยาเสพติดโดยใช้พื้นที่ (ตร.กม.)')
plt.show();

# %% [markdown]
# **คำอธิบาย** : จากกราฟผลการทำนายชนิดของยาเสพติดโดยใช้พื้นที่ (ตร.กม.) พบว่า ถ้าสมมติว่าจังหวัดนั้นมีพื้นที่ประมาณ 7,500 ตร.กม.ชนิดของยาเสพติดที่พบมากที่สุดก็คือ ยาบ้า , สมมติว่าจังหวัดนั้นมีพื้นที่ประมาณ 2,500 ตร.กม. ชนิดของยาเสพติดที่พบมากที่สุดก็คือ กระท่อม และสมมติว่าจังหวัดนั้นมีพื้นที่ประมาณ 20,000 ตร.กม. ชนิดของยาเสพติดที่พบมากที่สุดก็คือ ไอซ์ เป็นต้น

# %%
# กราฟผลการทำนายชนิดของยาเสพติดโดยใช้รายได้เฉลี่ยต่อเดือนของครัวเรือน (บาท)
plt.plot(X_test['รายได้เฉลี่ยต่อเดือนของครัวเรือน (บาท)'],perceptron2final_result,'Pg') 
plt.xlabel('รายได้เฉลี่ยต่อเดือนของครัวเรือน (บาท)')
plt.ylabel('ชนิดของยาเสพติด')
plt.title('ผลการทำนายชนิดของยาเสพติดโดยใช้รายได้เฉลี่ยต่อเดือนของครัวเรือน (บาท)')
plt.show();

# %% [markdown]
# **คำอธิบาย** : จากกราฟผลการทำนายชนิดของยาเสพติดโดยใช้รายได้เฉลี่ยต่อเดือนของครัวเรือน (บาท) พบว่า ถ้าสมมติว่าจังหวัดนั้นมีรายได้เฉลี่ยต่อเดือนของครัวเรือนประมาณ 15,000 บาท ชนิดของยาเสพติดที่พบมากที่สุดก็คือ ไอซ์ , สมมติว่าจังหวัดนั้นมีรายได้เฉลี่ยต่อเดือนของครัวเรือนประมาณ 30,000 บาท ชนิดของยาเสพติดที่พบมากที่สุดก็คือ กระท่อม  และสมมติว่าจังหวัดนั้นมีรายได้เฉลี่ยต่อเดือนของครัวเรือนประมาณ 25,000 บาท ชนิดของยาเสพติดที่พบมากที่สุดก็คือ ยาบ้า เป็นต้น

# %%
# กราฟผลการทำนายชนิดของยาเสพติดโดยใช้ปริมาณของกลางยาเสพติดทั้งหมด (กิโลกรัม)
plt.plot(X_test['ปริมาณของกลางยาเสพติดทั้งหมด (กิโลกรัม)'],perceptron2final_result,'Pr') 
plt.xlabel('ปริมาณของกลางยาเสพติดทั้งหมด (กิโลกรัม)')
plt.ylabel('ชนิดของยาเสพติด')
plt.title('ผลการทำนายชนิดของยาเสพติดโดยใช้ปริมาณของกลางยาเสพติดทั้งหมด (กิโลกรัม)')
plt.show();

# %% [markdown]
# **คำอธิบาย** : จากกราฟผลการทำนายชนิดของยาเสพติดโดยใช้ปริมาณของกลางยาเสพติดทั้งหมด (กิโลกรัม) พบว่า ถ้าสมมติว่าจังหวัดนั้นพบปริมาณของกลางยาเสพติดทั้งหมดประมาณ 1,200 กิโลกรัม  ชนิดของยาเสพติดที่พบมากที่สุดก็คือ ยาบ้า , สมมติว่าจังหวัดนั้นพบปริมาณของกลางยาเสพติดทั้งหมดประมาณ 3,000 กิโลกรัม  ชนิดของยาเสพติดที่พบมากที่สุดก็คือ กระท่อม และสมมติว่าจังหวัดนั้นพบปริมาณของกลางยาเสพติดทั้งหมดประมาณ 4,500 กิโลกรัม  ชนิดของยาเสพติดที่พบมากที่สุดก็คือ ไอซ์ เป็นต้น

# %%
# กราฟผลการทำนายชนิดของยาเสพติดโดยใช้เรื่องร้องเรียนและแจ้งเบาะแสยาเสพติดทั้งหมด (เรื่อง)
plt.plot(X_test['เรื่องร้องเรียนและแจ้งเบาะแสยาเสพติดทั้งหมด (เรื่อง)'],perceptron2final_result,'Pb') 
plt.xlabel('จำนวนเรื่องร้องเรียนและแจ้งเบาะแสยาเสพติดทั้งหมด (เรื่อง)')
plt.ylabel('ชนิดของยาเสพติด')
plt.title('ผลการทำนายชนิดของยาเสพติดโดยใช้จำนวนเรื่องร้องเรียนและแจ้งเบาะแสยาเสพติดทั้งหมด (เรื่อง)')
plt.show();

# %% [markdown]
# **คำอธิบาย** : จากกราฟผลการทำนายชนิดของยาเสพติดโดยใช้จำนวนเรื่องร้องเรียนและแจ้งเบาะแสยาเสพติดทั้งหมด (เรื่อง) พบว่า ถ้าสมมติว่าจังหวัดนั้นมีจำนวนเรื่องร้องเรียนและแจ้งเบาะแสยาเสพติดทั้งหมดประมาณ 400 เรื่อง ชนิดของยาเสพติดที่พบมากที่สุดก็คือ ยาบ้า , สมมติว่าจังหวัดนั้นมีจำนวนเรื่องร้องเรียนและแจ้งเบาะแสยาเสพติดทั้งหมดประมาณ 500 เรื่อง ชนิดของยาเสพติดที่พบมากที่สุดก็คือ กระท่อม และสมมติว่าจังหวัดนั้นมีจำนวนเรื่องร้องเรียนและแจ้งเบาะแสยาเสพติดทั้งหมดประมาณ 300 เรื่อง ชนิดของยาเสพติดที่พบมากที่สุดก็คือ ไอซ์  เป็นต้น

# %%
# กราฟผลการทำนายชนิดของยาเสพติดโดยใช้จำนวนคดีทั้งหมด (คดี)
plt.plot(X_test['จำนวนคดีทั้งหมด (คดี)'],perceptron2final_result,'Pm') 
plt.xlabel('จำนวนคดีทั้งหมด (คดี)')
plt.ylabel('ชนิดของยาเสพติด')
plt.title('ผลการทำนายชนิดของยาเสพติดโดยใช้จำนวนคดีทั้งหมด (คดี)')
plt.show();

# %% [markdown]
# **คำอธิบาย** : จากกราฟผลการทำนายชนิดของยาเสพติดโดยใช้จำนวนคดีทั้งหมด (คดี) พบว่า ถ้าสมมติว่าจังหวัดนั้นมีจำนวนคดีทั้งหมดประมาณ 7,500 คดี ชนิดของยาเสพติดที่พบมากที่สุดก็คือ กระท่อม , สมมติว่าจังหวัดนั้นมีจำนวนคดีทั้งหมดประมาณ 5,000 คดี ชนิดของยาเสพติดที่พบมากที่สุดก็คือ ยาบ้า  และสมมติว่าจังหวัดนั้นมีจำนวนคดีทั้งหมดประมาณ 7,000 คดี ชนิดของยาเสพติดที่พบมากที่สุดก็คือ ไอซ์ เป็นต้น

# %% [markdown]
# # **THE END**
